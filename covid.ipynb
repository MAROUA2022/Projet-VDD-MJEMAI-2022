# %%
import pandas as pd
import numpy as np

# %%
homme_df=pd.read_excel('C:\\Users\\GLOBALINFO\\Desktop\\homme.xlsx')

# %%
homme_df.transpose

# %%
homme_df
# Out:
#       mois  Maladies infectieuses  Covid-19  Tuberculose  Sida  \
# 0   Jan-20                     37         0            0     1
# 1   Feb-20                     41         0            0     2
# 2   Mar-20                     30       352            2     0
# 3   Apr-20                     25       688            0     2
# 4   May-20                     36        81            0     1
# 5   Jun-20                     29        12            0     6
# 6   Jul-20                     42        14            2     1
# 7   Aug-20                     33        17            1     2
# 8   Sep-20                     35        45            0     1
# 9   Oct-20                     24       313            0     0
# 10  Nov-20                     46      1676            0     1
# 11  Dec-20                      1      1715            1     0
#
#     Tumeurs malignes  Estomac  Gros intestin  Poumons  Sein  ...  \
# 0                820       22             49      187     0  ...
# ...

# %%
homme_df.columns
# Out:
# Index(['mois', 'Maladies infectieuses', 'Covid-19', 'Tuberculose', 'Sida',
#        'Tumeurs malignes', 'Estomac', 'Gros intestin', 'Poumons', 'Sein',
#        'Prostate', 'Diabète sucré', 'Démence', 'Appareil circulatoire',
#        'Cardiopathies toutes formes', 'Cardiopathies ischémiques',
#        'Embolie  infarctus pulmonaire', 'Maladies cérébro-vasculaires',
#        'Appareil respiratoire', 'Grippe', 'Pneumonie', 'Bronchite chronique',
#        'Asthme', 'Cirrhose du foie alcoolique', 'Organes urinaires',
#        'Anomalies congénitales', 'Causes de mortalité périnatale',
#        'Accidents et traumatismes', 'Accidents toutes les formes',
#        'Accidents de la route', 'Suicides'],
#       dtype='object')

# %%
homme_df.drop(['Tuberculose', 'Sida','Estomac', 'Gros intestin', 'Poumons', 'Sein',
       'Prostate', 'Cardiopathies toutes formes', 'Cardiopathies ischémiques',
       'Embolie  infarctus pulmonaire', 'Maladies cérébro-vasculaires', 'Grippe', 'Pneumonie', 'Bronchite chronique',
       'Asthme','Suicides', 'Accidents toutes les formes',
       'Accidents de la route']axis=1)

# %%
homme_df.to_csv(r,'homme.csv')

# %%
femme_df=pd.read_excel('C:\\Users\\GLOBALINFO\\Desktop\\femme.xlsx')

# %%
femme_df.transpose()

# %%
femme_df
# Out:
#       mois  Maladies infectieuses Covid-19  Tuberculose  Sida  \
# 0   Jan-20                     36        0            0     2
# 1   Feb-20                     34        0            1     0
# 2   Mar-20                     33      205            1     0
# 3   Apr-20                     31      645            0     2
# 4   May-20                     36       64            0     0
# 5   Jun-20                     31       10            0     1
# 6   Jul-20                     26        8            0     0
# 7   Aug-20                     36       17            0     0
# 8   Sep-20                     37       32            0     0
# 9   Oct-20                     23      258            1     0
# 10  Nov-20                     44    1'486            0     1
# 11  Dec-20                     47    1'667            0     0
#
#     Tumeurs malignes  Estomac  Gros intestin  Poumons  Sein  ...  Unnamed: 31  \
# 0                641       14             30      128   113  ...          NaN
# ...

# %%
femme_df.columns
# Out:
# Index(['mois', 'Maladies infectieuses', 'Covid-19', 'Tuberculose', 'Sida',
#        'Tumeurs malignes', 'Estomac', 'Gros intestin', 'Poumons', 'Sein',
#        'Col de l’utérus', 'Diabète sucré', 'Démence', 'Appareil circulatoire',
#        'Cardiopathies toutes formes', 'Cardiopathies ischémiques',
#        'Embolie  infarctus pulmonaire', 'Maladies cérébro-vasculaires',
#        'Appareil respiratoire', 'Grippe', 'Pneumonie', 'Bronchite chronique',
#        'Asthme', 'Cirrhose du foie alcoolique', 'Organes urinaires',
#        'Anomalies congénitales', 'Causes de mortalité périnatale',
#        'Accidents et traumatismes', 'Accidents toutes les formes',
#        'Accidents de la route', 'Suicides', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40'],
#       dtype='object')

# %%
femme_df.drop(['Tuberculose', 'Sida','Estomac', 'Gros intestin', 'Poumons', 'Sein',
       'Prostate', 'Cardiopathies toutes formes', 'Cardiopathies ischémiques',
       'Embolie  infarctus pulmonaire', 'Maladies cérébro-vasculaires', 'Grippe', 'Pneumonie', 'Bronchite chronique',
       'Asthme','Suicides', 'Accidents toutes les formes',
       'Accidents de la route']axis=1)

# %%
femme_df.to_csv(r,'Femme.csv')

# %%
total_df=pd.read_excel('C:\\Users\\GLOBALINFO\\Desktop\\total.xlsx')

# %%
total_df.transpose()

# %%
total_df.columns

# %%
total_df.drop(['Tuberculose', 'Sida','Estomac', 'Gros intestin', 'Poumons', 'Sein',
       'Prostate', 'Cardiopathies toutes formes', 'Cardiopathies ischémiques',
       'Embolie  infarctus pulmonaire', 'Maladies cérébro-vasculaires', 'Grippe', 'Pneumonie', 'Bronchite chronique',
       'Asthme','Suicides', 'Accidents toutes les formes',
       'Accidents de la route']axis=1)

# %%
total_df.to_csv(r,'total.csv')
